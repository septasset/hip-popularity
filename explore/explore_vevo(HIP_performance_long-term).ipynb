# %%
from __future__ import print_function, division
import os, bz2, json, time, sys
from datetime import timedelta

import math
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

vevo_path = "G:/MLCV dataset/quality_videos/vevo.json"

# %%
sys.path.insert(0, '../')
from pyhip import HIP

# %%
with open(vevo_path, "r") as f:
    vevo_json = f.readlines()

# %%
# FMVyXDU9bN4
record = json.loads(vevo_json[0])
print(record.keys())
cols = record['insights']
cols.keys()
# Out:
# dict_keys(['topicDetails', 'statistics', 'contentDetails', 'snippet', 'id', 'insights'])
# dict_keys(['startDate', 'dailyShare', 'totalShare', 'avgWatch', 'dailySubscriber', 'totalSubscriber', 'days', 'totalView', 'dailyView', 'dailyWatch'])

# %%
days = []
for line in vevo_json:
    vevo_record = json.loads(line)
    days.append(len(vevo_record['insights']['days'].split(",")))

# %%
pd_days = pd.DataFrame(days)
pd_days.describe()
# Out:
#                   0
# count  67649.000000
# mean     835.434404
# std      414.928623
# min        3.000000
# 25%      489.000000
# 50%      819.000000
# 75%     1187.000000
# max     1633.000000

# %%
vevo_videos = {}
for line in vevo_json:
    vevo_record = json.loads(line)
    try:
        vevo_videos[vevo_record['id']] = ([int(x) for x in vevo_record['insights']['dailyShare'].split(",")],\
                                      [int(x) for x in vevo_record['insights']['dailyView'].split(",")],\
                                      [float(x) for x in vevo_record['insights']['dailyWatch'].split(",")])
    except:
        continue
print("dataset size:", len(vevo_videos))
# Out:
# dataset size: 67556

# %% [markdown]
# ## Evaluate HIP on Vevo

# %%
# test_vid = 'FMVyXDU9bN4'
# daily_share, daily_view, daily_watch = vevo_videos[test_vid]
# print("Video {} has record of {} days".format(test_vid, len(daily_share)))
# num_train = 90
# num_test = 30
# num_initialization = 25

# %%
# hip_model = HIP()
# hip_model.initial(daily_share, daily_view, num_train, num_test, num_initialization)
# hip_model.fit_with_bfgs()
# hip_model.print_parameters()
# hip_model.plot_func('YouTubeID={0}'.format(test_vid))

# %%
# num_train = 600
# num_test = 200
# num_initialization = 25

# hip_model = HIP()
# hip_model.initial(daily_share, daily_view, num_train, num_test, num_initialization)
# hip_model.fit_with_bfgs()
# hip_model.print_parameters()
# hip_model.plot_func('YouTubeID={0}'.format(test_vid))

# %% [markdown]
# ### HIP performance variation wrt long term

# %%
start_time = time.time()
size = 30
count = 0

num_train = 90
num_test = 540
num_initialization = 25

preds_y = []
gts_y = []
test_vids = []
for test_vid in list(vevo_videos.keys()):
    daily_share, daily_view, daily_watch = vevo_videos[test_vid]
    # filter videos with insufficient record history
    if len(daily_view) <= (num_train + num_test): continue
    test_vids.append(test_vid)
    hip_model = HIP()
    hip_model.initial(daily_share, daily_view, num_train, num_test, num_initialization)
    hip_model.fit_with_bfgs()
    
    y_predict = hip_model.predict(hip_model.get_parameters_abbr(), hip_model.x)
    preds_y.append(y_predict)
    gts_y.append(np.array(hip_model.y))
    count += 1
    
    if count >= size: break
    
    if count % (size/5) == 0:
        print('>>> {1}/{2} Elasped time: {0}'.format(str(timedelta(seconds=time.time() - start_time))[:-3], count, size))
# Out:
# --- Finish initialization set 5...
# --- Finish initialization set 10...
# --- Finish initialization set 15...
# --- Finish initialization set 20...
# --- Finish initialization set 25...
# --- Model fitting RMSE: 166.03
# --- Model forecast RMSE: 57.51
# --- Finish initialization set 5...
# --- Finish initialization set 10...
# --- Finish initialization set 15...
# --- Finish initialization set 20...
# --- Finish initialization set 25...
# --- Model fitting RMSE: 591.11
# --- Model forecast RMSE: 105.90
# --- Finish initialization set 5...
# --- Finish initialization set 10...
# --- Finish initialization set 15...
# --- Finish initialization set 20...
# --- Finish initialization set 25...
# --- Model fitting RMSE: 228.89
# --- Model forecast RMSE: 135.54
# --- Finish initialization set 5...
# --- Finish initialization set 10...
# --- Finish initialization set 15...
# --- Finish initialization set 20...
# --- Finish initialization set 25...
# --- Model fitting RMSE: 1885.75
# --- Model forecast RMSE: 9409.85
# --- Finish initialization set 5...
# --- Finish initialization set 10...
# --- Finish initialization set 15...
# --- Finish initialization set 20...
# --- Finish initialization set 25...
# --- Model fitting RMSE: 1628.79
# --- Model forecast RMSE: 22764.02
# --- Finish initialization set 5...
# --- Finish initialization set 10...
# --- Finish initialization set 15...
# --- Finish initialization set 20...
# --- Finish initialization set 25...
# --- Model fitting RMSE: 1856.98
# --- Model forecast RMSE: 9571.78
# >>> 6/30 Elasped time: 0:12:39.278
# --- Finish initialization set 5...
# --- Finish initialization set 10...
# --- Finish initialization set 15...
# --- Finish initialization set 20...
# --- Finish initialization set 25...
# --- Model fitting RMSE: 111.62
# --- Model forecast RMSE: 1339.22
# --- Finish initialization set 5...
# --- Finish initialization set 10...
# --- Finish initialization set 15...
# --- Finish initialization set 20...
# --- Finish initialization set 25...
# --- Model fitting RMSE: 210.32
# --- Model forecast RMSE: 332.82
# --- Finish initialization set 5...
# --- Finish initialization set 10...
# --- Finish initialization set 15...
# --- Finish initialization set 20...
# --- Finish initialization set 25...
# --- Model fitting RMSE: 400.98
# --- Model forecast RMSE: 526.13
# --- Finish initialization set 5...
# --- Finish initialization set 10...
# --- Finish initialization set 15...
# --- Finish initialization set 20...
# --- Finish initialization set 25...
# --- Model fitting RMSE: 10.84
# --- Model forecast RMSE: 25.04
# --- Finish initialization set 5...
# --- Finish initialization set 10...
# --- Finish initialization set 15...
# --- Finish initialization set 20...
# --- Model fitting RMSE: 283.88
# --- Model forecast RMSE: 332.32
# --- Finish initialization set 5...
# --- Finish initialization set 10...
# --- Finish initialization set 15...
# --- Finish initialization set 20...
# --- Finish initialization set 25...
# --- Model fitting RMSE: 6.94
# --- Model forecast RMSE: 59.31
# >>> 12/30 Elasped time: 0:22:38.431
# --- Finish initialization set 5...
# --- Finish initialization set 10...
# --- Finish initialization set 15...
# --- Finish initialization set 20...
# --- Finish initialization set 25...
# --- Model fitting RMSE: 100.15
# --- Model forecast RMSE: 978.25
# --- Finish initialization set 5...
# --- Finish initialization set 10...
# --- Finish initialization set 15...
# --- Finish initialization set 20...
# --- Finish initialization set 25...
# --- Model fitting RMSE: 823.68
# --- Model forecast RMSE: 2021.23
# --- Finish initialization set 5...
# --- Finish initialization set 10...
# --- Finish initialization set 15...
# --- Finish initialization set 20...
# --- Finish initialization set 25...
# --- Model fitting RMSE: 307.33
# --- Model forecast RMSE: 267.86
# --- Finish initialization set 5...
# --- Finish initialization set 10...
# --- Finish initialization set 15...
# --- Finish initialization set 20...
# --- Finish initialization set 25...
# --- Model fitting RMSE: 544.88
# --- Model forecast RMSE: 469.02
# --- Finish initialization set 5...
# --- Finish initialization set 10...
# --- Finish initialization set 15...
# --- Finish initialization set 20...
# --- Finish initialization set 25...
# --- Model fitting RMSE: 4662.98
# --- Model forecast RMSE: 991.08
# --- Finish initialization set 5...
# --- Finish initialization set 10...
# --- Finish initialization set 15...
# --- Finish initialization set 20...
# --- Finish initialization set 25...
# --- Model fitting RMSE: 40.06
# --- Model forecast RMSE: 134.72
# >>> 18/30 Elasped time: 0:28:30.721
# --- Finish initialization set 5...
# --- Finish initialization set 10...
# --- Finish initialization set 15...
# --- Finish initialization set 20...
# --- Finish initialization set 25...
# --- Model fitting RMSE: 150.72
# --- Model forecast RMSE: 114.21
# --- Finish initialization set 5...
# --- Finish initialization set 10...
# --- Finish initialization set 15...
# --- Finish initialization set 20...
# --- Finish initialization set 25...
# --- Model fitting RMSE: 53.57
# --- Model forecast RMSE: 107.93
# --- Finish initialization set 5...
# --- Finish initialization set 10...
# --- Finish initialization set 15...
# --- Finish initialization set 20...
# --- Finish initialization set 25...
# --- Model fitting RMSE: 12.71
# --- Model forecast RMSE: 65.11
# --- Finish initialization set 5...
# --- Finish initialization set 10...
# --- Finish initialization set 15...
# --- Finish initialization set 20...
# --- Finish initialization set 25...
# --- Model fitting RMSE: 166.20
# --- Model forecast RMSE: 249.40
# --- Finish initialization set 5...
# --- Finish initialization set 10...
# --- Finish initialization set 15...
# --- Finish initialization set 20...
# --- Finish initialization set 25...
# --- Model fitting RMSE: 104.74
# --- Model forecast RMSE: 649.66
# --- Finish initialization set 5...
# --- Finish initialization set 10...
# --- Finish initialization set 15...
# --- Finish initialization set 20...
# --- Finish initialization set 25...
# --- Model fitting RMSE: 172.60
# --- Model forecast RMSE: 298.16
# >>> 24/30 Elasped time: 0:34:10.512
# --- Finish initialization set 5...
# --- Finish initialization set 10...
# --- Finish initialization set 15...
# --- Finish initialization set 20...
# --- Finish initialization set 25...
# --- Model fitting RMSE: 248.85
# --- Model forecast RMSE: 994.86
# --- Finish initialization set 5...
# --- Finish initialization set 10...
# --- Finish initialization set 15...
# --- Finish initialization set 20...
# --- Finish initialization set 25...
# --- Model fitting RMSE: 698.47
# --- Model forecast RMSE: 1291.38
# --- Finish initialization set 5...
# --- Finish initialization set 10...
# --- Finish initialization set 15...
# --- Finish initialization set 20...
# --- Finish initialization set 25...
# --- Model fitting RMSE: 173.18
# --- Model forecast RMSE: 294.90
# --- Finish initialization set 5...
# --- Finish initialization set 10...
# --- Finish initialization set 15...
# --- Finish initialization set 20...
# --- Finish initialization set 25...
# --- Model fitting RMSE: 211.69
# --- Model forecast RMSE: 127.29
# --- Finish initialization set 5...
# --- Finish initialization set 10...
# --- Finish initialization set 15...
# --- Finish initialization set 20...
# --- Finish initialization set 25...
# --- Model fitting RMSE: 1052.88
# --- Model forecast RMSE: 1077.53
# --- Finish initialization set 5...
# --- Finish initialization set 10...
# --- Finish initialization set 15...
# --- Finish initialization set 20...
# --- Finish initialization set 25...
# --- Model fitting RMSE: 1009.99
# --- Model forecast RMSE: 1733.15

# %%
preds_y_eval = []
gts_y_eval = []
eval_days = np.arange(30, num_test, 10)
for i in range(len(preds_y)):
    pred_y_accu = [np.sum(preds_y[i][:num_train+eval_day]) for eval_day in eval_days]
    gt_y_accu = [np.sum(gts_y[i][:num_train+eval_day]) for eval_day in eval_days]
    preds_y_eval.append(pred_y_accu)
    gts_y_eval.append(gt_y_accu)

# %%
df_preds_eval = pd.DataFrame(preds_y_eval, columns =eval_days)#, index = test_vids)
df_gts_eval = pd.DataFrame(gts_y_eval, columns =eval_days)#, index = test_vids)
pop_scales = np.linspace(0, 1, len(df_preds_eval[eval_days[0]]))

df_perc_errors = []
for eval_day in eval_days:
    perc_error = []
    pred_sort = df_preds_eval.sort_values(by=[eval_day], inplace=False)
    gt_sort = df_gts_eval.sort_values(by=[eval_day], inplace=False)
    pred_sort[eval_day] = pop_scales
    gt_sort[eval_day] = pop_scales
    
    for ind in pred_sort.index:
        perc_error.append(np.abs(pred_sort.loc[ind, eval_day]-gt_sort.loc[ind, eval_day]))
    df_perc_error = pd.DataFrame(perc_error, columns =[eval_day], index = pred_sort.index)
    df_perc_errors.append(df_perc_error)

mean_perc_errors = []
for df in df_perc_errors:
    mean_perc_errors.append(np.sum(df.to_numpy())/size)
df_mean_perc_errors = pd.DataFrame([mean_perc_errors], columns =eval_days)
display(df_mean_perc_errors)
# Out:
#         30        40        50        60        70        80        90   \
# 0  0.016092  0.016092  0.016092  0.022989  0.022989  0.027586  0.032184
#
#         100       110      120  ...       440       450       460       470  \
# 0  0.036782  0.032184  0.03908  ...  0.066667  0.068966  0.071264  0.071264
#
#         480       490       500       510       520       530
# 0  0.071264  0.071264  0.071264  0.071264  0.071264  0.071264
#
# [1 rows x 51 columns]

# %%
fig = plt.figure(figsize=(12, 6))
ax1 = fig.add_subplot(111)
ax1.plot(df_mean_perc_errors.loc[0,:])
ax1.set_xlabel("test days")
ax1.set_ylabel("mean absolute percentile error")
pass
